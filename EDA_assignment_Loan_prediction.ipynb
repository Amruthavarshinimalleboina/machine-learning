# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_name="C:\\Users\\91798\\Documents\\Python Scripts\\loan prediction.csv"
pd.read_csv(file_name)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
file_name="C:\\Users\\91798\\Documents\\Python Scripts\\loan prediction.csv"
loan_prediction=pd.read_csv(file_name,sep=',')

# %%
loan_prediction
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
type(loan_prediction)
# Out:
# pandas.core.frame.DataFrame

# %%
loan_prediction.shape
# Out:
# (614, 13)

# %%
loan_prediction.iloc[1:6,0:3]
# Out:
#     Loan_ID Gender Married
# 1  LP001003   Male     Yes
# 2  LP001005   Male     Yes
# 3  LP001006   Male     Yes
# 4  LP001008   Male      No
# 5  LP001011   Male     Yes

# %%
loan_prediction.take([0,1,2],axis=1).take([0,1,2,3,4])
# Out:
#     Loan_ID Gender Married
# 0  LP001002   Male      No
# 1  LP001003   Male     Yes
# 2  LP001005   Male     Yes
# 3  LP001006   Male     Yes
# 4  LP001008   Male      No

# %%
loan_prediction.iloc[100:106,5:9]
# Out:
#     Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount
# 100            No             4288             3263.0       133.0
# 101            No             4843             3806.0       151.0
# 102            No            13650                0.0         NaN
# 103            No             4652             3583.0         NaN
# 104            No             3816              754.0       160.0
# 105            No             3052             1030.0       100.0

# %%
loan_prediction.iloc[100:106,:]
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 100  LP001345   Male     Yes          2  Not Graduate            No
# 101  LP001349   Male      No          0      Graduate            No
# 102  LP001350   Male     Yes        NaN      Graduate            No
# 103  LP001356   Male     Yes          0      Graduate            No
# 104  LP001357   Male     NaN        NaN      Graduate            No
# 105  LP001367   Male     Yes          1      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 100             4288             3263.0       133.0             180.0
# 101             4843             3806.0       151.0             360.0
# 102            13650                0.0         NaN             360.0
# 103             4652             3583.0         NaN             360.0
# 104             3816              754.0       160.0             360.0
# ...

# %%
index=[100,101,102]
loan_prediction.iloc[index]
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 100  LP001345   Male     Yes          2  Not Graduate            No
# 101  LP001349   Male      No          0      Graduate            No
# 102  LP001350   Male     Yes        NaN      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 100             4288             3263.0       133.0             180.0
# 101             4843             3806.0       151.0             360.0
# 102            13650                0.0         NaN             360.0
#
#      Credit_History Property_Area Loan_Status
# 100             1.0         Urban           Y
# 101             1.0     Semiurban           Y
# 102             1.0         Urban           Y

# %%
index_row=[100,101,102]
index_column=[7,8,9]
loan_prediction.iloc[index_row,index_column]
# Out:
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term
# 100             3263.0       133.0             180.0
# 101             3806.0       151.0             360.0
# 102                0.0         NaN             360.0

# %%
loan_prediction.iloc[[100,101,102],[1,2]]
# Out:
#     Gender Married
# 100   Male     Yes
# 101   Male      No
# 102   Male     Yes

# %%
columns=['Education']
rows=[100,101,102]
loan_prediction.loc[rows,columns]
# Out:
#         Education
# 100  Not Graduate
# 101      Graduate
# 102      Graduate

# %%
plt.bar plot
# Out:
#   Cell In[46], line 1
#     plt.bar plot
#             ^
# SyntaxError: invalid syntax

# %%
loan_prediction
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
type(loan_prediction)
# Out:
# pandas.core.frame.DataFrame

# %%
loan_prediction.shape
# Out:
# (614, 13)

# %%
type(loan_prediction.shape)
# Out:
# tuple

# %%
a=(614,13)
a[0],[1]
# Out:
# (614, [1])

# %%
print("number of rows are:",loan_prediction.shape[0])
print("number of columns are:",loan_prediction.shape[1])
# Out:
# number of rows are: 614
# number of columns are: 13

# %%
len(loan_prediction)
# Out:
# 614

# %%
loan_prediction.size
# Out:
# 7982

# %%
614*13
# Out:
# 7982

# %%
import pandas as pd

# %%
file_name="C:\\Users\\91798\\Documents\\Python Scripts\\loan prediction.csv"
loan_prediction=pd.read_csv(file_name)

# %%
loan_prediction
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_prediction.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
dir(loan_prediction)
# Out:
# ['ApplicantIncome',
#  'CoapplicantIncome',
#  'Credit_History',
#  'Dependents',
#  'Education',
#  'Gender',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Loan_ID',
#  'Loan_Status',
#  'Married',
#  'Property_Area',
#  'Self_Employed',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
# ...

# %%
loan_prediction.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
loan_prediction.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
# 2  LP001005   Male     Yes          0  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y

# %%
loan_prediction.tail(3)
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N

# %%
loan_prediction.loc[[100,200,300],['Gender','Married','LoanAmount']]
# Out:
#     Gender Married  LoanAmount
# 100   Male     Yes       133.0
# 200   Male     Yes        90.0
# 300   Male     Yes        93.0

# %%
rows=[100,200,300]
columns=['Gender','Married','LoanAmount']
loan_prediction.loc[rows,columns]
# Out:
#     Gender Married  LoanAmount
# 100   Male     Yes       133.0
# 200   Male     Yes        90.0
# 300   Male     Yes        93.0

# %%
loan_prediction.iloc[[

# %%
cols_list=list(loan_prediction.columns)
cols_list.index('Property_Area')
# Out:
# 11

# %%
loan_prediction.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
type(loan_prediction.dtypes)
# Out:
# pandas.core.series.Series

# %%
dict(loan_prediction.dtypes)
# Out:
# {'Loan_ID': dtype('O'),
#  'Gender': dtype('O'),
#  'Married': dtype('O'),
#  'Dependents': dtype('O'),
#  'Education': dtype('O'),
#  'Self_Employed': dtype('O'),
#  'ApplicantIncome': dtype('int64'),
#  'CoapplicantIncome': dtype('float64'),
#  'LoanAmount': dtype('float64'),
#  'Loan_Amount_Term': dtype('float64'),
#  'Credit_History': dtype('float64'),
#  'Property_Area': dtype('O'),
#  'Loan_Status': dtype('O')}

# %%
import seaborn as sns

# %%
file_name="C:\\Users\\91798\\Documents\\Python Scripts\\loan prediction.csv"
loan_prediction=pd.read_csv(file_name)

# %%
loan_prediction
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
order_keys=loan_prediction

# %%
loan_prediction
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
sns.countplot(data=loan_prediction,
             x='Loan_ID')
# Out:
# <Axes: xlabel='Loan_ID', ylabel='count'>

# %%
sns.countplot(data=loan_prediction,
             x='Married')
# Out:
# <Axes: xlabel='Married', ylabel='count'>

# %%
import matplotlib.pyplot as plt

# %%
plt.xlabel("Gender")
plt.ylabel("Applicantincome")
plt.title('countplot')
# Out:
# Text(0.5, 1.0, 'countplot')

# %%
order_keys=loan_prediction['Gender'],value_count().keys()
order_keys
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 order_keys=loan_prediction['Gender'],value_count().keys()
#       2 order_keys
#
# NameError: name 'value_count' is not defined

# %%
import seaborn as sns
import pandas as pd

# %%
file_name="C:\\Users\\91798\\Documents\\Python Scripts\\loan prediction.csv"
loan_prediction=pd.read_csv(file_name)
loan_prediction
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
sns.countplot(x='Gender',data=loan_prediction)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
ax=sns.countplot(x='Property_Area',data=loan_prediction)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '202'), Text(0, 0, '179'), Text(0, 0, '233')]

# %% [markdown]
# $info$

# %%
loan_prediction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# $isnull$

# %%
loan_prediction.isnull()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False        True             False
# ...

# %%
loan_prediction.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
import numpy as np

# %%
data=loan_prediction['ApplicantIncome']
np.percentile(data,100)
# Out:
# 81000.0

# %%
data=loan_prediction['ApplicantIncome']
per_25=round(np.percentile(data,25),2)
per_50=round(np.percentile(data,50),2)
per_75=round(np.percentile(data,75),2)
per_20=round(np.percentile(data,20),2)
print(per_25,per_50,per_75,per_20)
# Out:
# 2877.5 3812.5 5795.0 2605.4

# %%
np.quantile(data,0.25)                         #quantile ranges 0 to 1
                                            #percentile ranges 0 to 100
# Out:
# 2877.5

# %%
data=loan_prediction['ApplicantIncome']
quan_25=round(np.quantile(data,0.25),2)
quan_50=round(np.quantile(data,0.50),2)
quan_75=round(np.quantile(data,0.75),2)
quan_20=round(np.quantile(data,0.20),2)
print(quan_25,quan_50,quan_75,quan_20)
# Out:
# 2877.5 3812.5 5795.0 2605.4

# %%
dict2=[]
dict2=loan_prediction['ApplicantIncome'].mean()                       #for finding mean
dict2
# Out:
# 5403.459283387622

# %%
dict2=loan_prediction['ApplicantIncome'].median()          
dict2
# Out:
# 3812.5

# %%
round(loan_prediction['ApplicantIncome'].std(),2)
# Out:
# 6109.04

# %%
round(loan_prediction['ApplicantIncome'].max(),2)
# Out:
# 81000

# %%
loan_prediction['ApplicantIncome'].min()
# Out:
# 150

# %%
loan_prediction['ApplicantIncome'].count()
# Out:
# 614

# %%
round(np.percentile(data,25),2)
# Out:
# 2877.5

# %%
dict2=[]
dict2=round(loan_prediction['ApplicantIncome'].mean(),2)
dict2=round(loan_prediction['ApplicantIncome'].median(),2)
dict2=round(loan_prediction['ApplicantIncome'].std(),2)
dict2=round(loan_prediction['ApplicantIncome'].max(),2)
dict2=round(loan_prediction['ApplicantIncome'].min(),2)
dict2=round(loan_prediction['ApplicantIncome'].count(),2)
dict2=round(np.percentile(data,25),2)
dict2=round(np.percentile(data,50),2)
dict2=round(np.percentile(data,75),2)

pd.DataFrame.dict2(data, orient=='index',
                       ('ApplicantIncome'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[82], line 12
#       9 dict2=round(np.percentile(data,50),2)
#      10 dict2=round(np.percentile(data,75),2)
# ---> 12 pd.DataFrame.dict2(data, orient=='index',
#      13                        ('ApplicantIncome'))
#
# AttributeError: type object 'DataFrame' has no attribute 'dict2'

# %%
dict2.values()
pd.DataFrame(dict2,values(),
            columns=['ApplicantIncome'],
            index=dict2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 dict2.values()
#       2 pd.DataFrame(dict2,values(),
#       3             columns=['ApplicantIncome'],
#       4             index=dict2)
#
# AttributeError: 'numpy.float64' object has no attribute 'values'

# %% [markdown]
# $Histogram$

# %%
data=loan_prediction('ApplicantIncome')
frequency,interval,n=plt.hist(data,bins=40)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 data=loan_prediction('ApplicantIncome')
#       2 frequency,interval,n=plt.hist(data,bins=40)
#
# TypeError: 'DataFrame' object is not callable

# %%
import matplotlib.pyplot as plt

# %%
data=loan_prediction['ApplicantIncome']
plt.hist(data,
        bins=40,
        color='b')
plt.xlabel("intervals")
plt.ylabel("count")
plt.title("Histogram")
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
import seaborn as sns

# %%
sns.histplot(loan_prediction)
plt.show()

# %% [markdown]
# $Box$ $plot$

# %%
sns.boxplot(loan_prediction)
plt.show()

# %%
q1=np.quantile(data,0.25)
q2=round(np.quantile(data,0.50),2)
q3=round(np.quantile(data,0.75),2)
IQR=(q3-q1)
LB=q1-1.5*IQR
UB=q3+1.5*IQR
    
print("q1:",q1)
print("q2:",q2)
print("q3:",q3)
print("IQR:",IQR)
print("LB:",LB)
print("UB:",UB)
# Out:
# q1: 2877.5
# q2: 3812.5
# q3: 5795.0
# IQR: 2917.5
# LB: -1498.75
# UB: 10171.25

# %%
data=loan_prediction['ApplicantIncome']
con1=data<LB
con2=data>UB
con1|con2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 609    False
# 610    False
# 611    False
# 612    False
# 613    False
# Name: ApplicantIncome, Length: 614, dtype: bool

# %%
loan_prediction[con1|con2]
loan_prediction[con1
               &
               con2]
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status]
# Index: []
